# %%
# %matplotlib notebook

# %%
print('ok')
# Out:
# ok

# %%
import numpy as np
import pandas as pd

# %%
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20

# %%
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib

# %%
data = np.arange(10)

# %%
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure() #空の図にはプロットできない subplotを一つ以上作らないといけない
ax1 = fig.add_subplot(2,2,1)
ax4 = fig.add_subplot(2,2,4)
ax2 = fig.add_subplot(2,2,3) # またまとめて型を入れるようにすること
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print('プロットしたものは最後の部分に表示される')
plt.plot(np.random.randn(50).cumsum(),'r-')
# Out:
# プロットしたものは最後の部分に表示される

# %%
_ = ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)

# %%
ax4.scatter(np.arange(30),np.arange(30) + 3*np.random.randn(30))

# %%
_
# Out:
# (array([ 2.,  0.,  2.,  3.,  3.,  4.,  6.,  9.,  7.,  6., 15.,  6.,  7.,
#         10., 10.,  2.,  3.,  2.,  1.,  2.]),
#  array([-2.30423388, -2.08054911, -1.85686435, -1.63317958, -1.40949482,
#         -1.18581005, -0.96212528, -0.73844052, -0.51475575, -0.29107099,
#         -0.06738622,  0.15629855,  0.37998331,  0.60366808,  0.82735284,
#          1.05103761,  1.27472237,  1.49840714,  1.72209191,  1.94577667,
#          2.16946144]),
#  <a list of 20 Patch objects>)

# %%
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, axes = plt.subplots(2,3)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c639400>,
# ...
#       dtype=object)

# %%
axes[0,1]

# %%
plt.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=None,hspace=None)

# %%
fig,axes = plt.subplots(2,2,sharex=True,sharey=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)

# %%
print('wsapceはwidthの図の中のspace,hspaceはheightのスペースのパーセンテージを表す')
# Out:
# wsapceはwidthの図の中のspace,hspaceはheightのスペースのパーセンテージを表す

# %%
ax.plot(x,y,'g--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f01af4f624a7> in <module>
# ----> 1 ax.plot(x,y,'g--')
#
# NameError: name 'ax' is not defined

# %%
plot?

# %%
plt.plot? # plotのdocstringを呼び出す

# %%
from numpy.random import randn

# %%
# %matplotlib inline

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data,'b--',label='Default')
plt.plot(data,'r-',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')

# %%
axes[0,1].get_xlim()

# %%
fig = plt.figure()

# %%
ax = fig.add_subplot(1,1,1)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
fig

# %%
ticks = ax.set_xticks([0,250,500,750,1000])

# %%
fig

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation=30,fontsize='small')

# %%
fig

# %%
ax.set_title('My first matplotlib plot')

# %%
ax.set_xlabel('Stages')

# %%
props = {
    'ylabel':'numbers',
    'yticks':[0,1,2,3,4,5]
}

# %%
ax.set(**props)

# %%
fig

# %%
from numpy.random import randn

# %%
fig = plt.figure();ax = fig.add_subplot(1,1,1)

# %%
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
fig

# %%
ax.legend(loc='best')

# %%
fig

# %%
ax.legend? # bestは邪魔にならない場所を自動的に呼び出す

# %%
# x = 0
# y = -30
# ax.text(x, y,'Hello world',family='monospace',fontsize=10)

# %%
fig

# %%
from datetime import datetime

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

# %%
data = pd.read_csv('spx.csv',index_col=0,parse_dates=True)

# %%
spx = data['SPX']

# %%
spx

# %%
spx.plot(ax=ax, style='k-')

# %%
crisis_data = [
    (datetime(2007,10,11),'Peak of bull market'),
    (datetime(2008,3,12),'Bear sterns Fails'),
    (datetime(2008,9,15),'Lehman Bankruptly')
]

# %%
for date, label in crisis_data:
    ax.annotate(label,xy=(date,spx.asof(date) + 75),
               xytext = (date,spx.asof(date)+225),
               arrowprops=dict(facecolor='black',headwidth=4,width=2,headlength=4),
                horizontalalignment='left',verticalalignment='top')

# %%
ax.set_xlim(['1/1/2007','1/1/2011'])

# %%
ax.set_ylim([600,1800])

# %%
ax.set_title('Important dates in the 2008-2009 financial crisis')

# %%
import matplotlib.dates as dates
datefmt = dates.DateFormatter('%Y年%m月')
ax.xaxis.set_major_formatter(datefmt)
ax.set_xlim(['1/1/2007','1/1/2011'])
ax.set_ylim([600,1800])
ax.set_title('2008年から2009年の金融危機の重要な日ずけ')

# %%
fig

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((0.2,0.75),0.4,0.15,color='k',alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
# これらの図形はpatchオブジェクトとして扱われる
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
fig.savefig('figpath.svg') # 最後に作成された図を保存する

# %%
plt.savefig('figpath.png',dpi=400,bbox_inches='tight')

# %%
fig.savefig('figpath.png',dpi=400,bbox_inches='tight')

# %%
plt.rc('figure',figsize=(10,10))

# %%
font_options = {
    'family':'monospace',
    'weight':'bold'
}

# %%
plt.rc('font',**font_options)

# %%
s = pd.Series(np.random.randn(10).cumsum(),index = np.arange(0,100,10))

# %%
s

# %%
s.plot() # use_index=False でインデックスを抑えれる

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))

# %%
df

# %%
df.plot()

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(2,1)

# %%
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='b',alpha=0.7)
data.plot.barh(ax=axes[1],color='r',alpha=0.7)

# %%
fig

# %%
np.random.seed(12348)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))

# %%
df

# %%
df.plot.bar()

# %%
plt.tick_params( labelcolor='w',  color='r')

# %%
df.plot.barh()

# %%
import matplotlib
matplotlib.matplotlib_fname()
print(matplotlib.rcParams['xtick.color'])

# %%
from matplotlib import rcParams
rcParams.update({'xtick.color':'w','ytick.color':'w'})

# %%
df.plot.barh()

# %%
   tips = pd.read_csv('tips.csv')

# %%
party_counts = pd.crosstab(tips['day'],tips['size']) # クロス集計できる

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:,2:5]

# %%
party_pcts =  party_counts.div(party_counts.sum(1),axis=0)

# %%
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import seaborn as sns

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
tips['tip_pct'] = tips['tip']/(tips['total_bill'] - tips['tip'])

# %%
# %matplotlib inline
from matplotlib import rcParams
rcParams.update({'xtick.color':'w','ytick.color':'w','axes.labelcolor':'gold'})
sns.barplot(x='tip_pct',y='day',data=tips,orient='h')

# %%
sns.set(style='whitegrid') # 格子を入れることができる
sns.barplot(x='tip_pct',y='day',hue='time',data=tips,orient='h')

# %%
tips['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
# 5      Dinner
# 6      Dinner
# 7      Dinner
# 8      Dinner
# 9      Dinner
#         ...
# 234    Dinner
# 235    Dinner
# 236    Dinner
# 237    Dinner
# 238    Dinner
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: object

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
tips['tip_pct'].plot.density()

# %%
comp1 = np.random.normal(0,1,size=200) # 正規乱数を出力
comp2 = np.random.normal(10,2,size=200)
values  = pd.Series(np.concatenate([comp1,comp2]))
values
# Out:
# 0       0.706406
# 1      -1.099218
# 2      -0.070197
# 3      -0.792257
# 4       1.331669
# 5      -0.818813
# 6      -0.075326
# 7       0.571188
# 8       1.190274
# 9       1.800285
#          ...
# 390    11.455487
# 391    10.322308
# 392    14.540438
# 393     7.891794
# 394    10.671974
# 395     6.450261
# 396    14.838006
# 397     9.709689
# 398    13.706994
# 399     7.019977
# Length: 400, dtype: float64

# %%
sns.distplot(values,bins=100,color='b') # ヒストグラムと、密度推定の両方を行う

# %%
macro = pd.read_csv('macrodata.csv')
data = macro[['cpi','m1','tbilrate','unemp']]
trans_data = np.log(data).diff().dropna()
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot('m1','unemp',data=trans_data)
plt.title('Changes in log %s versus log %s' % ('m1','unemp'))
# Out:
# Text(0.5,1,'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data,diag_kind='kde',plot_kws={'alpha' : 0.2})

# %%
sns.factorplot(x='day',y='tip_pct',hue='time',col='smoker',kind='bar',data=tips[tips.tip_pct < 1])
# Out:
# /Users/humu/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='tip_pct',row='time',col='smoker',kind='bar',data=tips[tips.tip_pct < 1])

# %%
sns.factorplot(x='tip_pct',y='day',kind='box',data=tips[tips.tip_pct < 0.5])
